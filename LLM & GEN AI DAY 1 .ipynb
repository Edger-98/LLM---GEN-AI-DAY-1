# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install -U -q "google-generativeai>=0.8.3"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
from IPython.display import HTML, Markdown, display

# %%
from kaggle_secrets import UserSecretsClient

GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# %%
flash = genai.GenerativeModel('gemini-1.5-flash')
response = flash.generate_content("Explain why cristiano ronaldo is better than messi.")
print(response.text)
# Out:
# It's impossible to definitively say that Cristiano Ronaldo is "better" than Lionel Messi, or vice versa. Both are phenomenal footballers with distinct strengths and styles.
#
# Here's a breakdown of their contrasting strengths and why the "better" argument is subjective:
#
# **Cristiano Ronaldo:**
#
# * **Physical prowess:** Renowned for his athleticism, jumping ability, and powerful shooting.
# * **Aerial dominance:**  A threat in the air, scoring many goals with headers.
# * **Versatility:** Played in multiple positions, showcasing his adaptability.
# * **Goal-scoring machine:** Holds numerous records for goals in various competitions.
# * **Strong mentality:** Known for his focus, dedication, and competitive spirit.
#
# **Lionel Messi:**
#
# * **Dribbling wizardry:** Unmatched dribbling skills, effortlessly weaving past defenders.
# * **Passing artistry:**  Exceptional vision and passing range, creating countless chances.
# ...

# %%
Markdown(response.text)
# Out:
# It's impossible to definitively say that Cristiano Ronaldo is "better" than Lionel Messi, or vice versa. Both are phenomenal footballers with distinct strengths and styles.
#
# Here's a breakdown of their contrasting strengths and why the "better" argument is subjective:
#
# **Cristiano Ronaldo:**
#
# * **Physical prowess:** Renowned for his athleticism, jumping ability, and powerful shooting.
# * **Aerial dominance:**  A threat in the air, scoring many goals with headers.
# * **Versatility:** Played in multiple positions, showcasing his adaptability.
# * **Goal-scoring machine:** Holds numerous records for goals in various competitions.
# * **Strong mentality:** Known for his focus, dedication, and competitive spirit.
#
# **Lionel Messi:**
#
# * **Dribbling wizardry:** Unmatched dribbling skills, effortlessly weaving past defenders.
# * **Passing artistry:**  Exceptional vision and passing range, creating countless chances.
# ...

# %%
chat = flash.start_chat(history=[])
response = chat.send_message('Hello! My name is chineme.')
print(response.text)
# Out:
# Hello Chineme! It's nice to meet you. 😊 What can I do for you today?

# %%
chat = flash.start_chat(history=[])
response = chat.send_message('Hello! My name is chineme.')
print(response.text)
# Out:
# Hello Chineme! It's nice to meet you. 😊  What can I do for you today?

# %%
chat = flash.start_chat(history=[])
response = chat.send_message('Can you tell where im from ')
print(response.text)
# Out:
# I do not have access to personal information about you, including your location.
#
# To tell you where you are from, I would need more information from you. For example, you could tell me:
#
# * **Your current location:** "I'm currently in London."
# * **Your hometown:** "I grew up in New York City."
# * **Your nationality:** "I am a citizen of Canada."
# * **Your language:** "I speak Spanish as my first language."
#
# Let me know if you can provide me with some details! 😊

# %%
chat = flash.start_chat(history=[])
response = chat.send_message('take a guess based on my name. use that to compare all countries ')
print(response.text)
# Out:
# Please tell me your name so I can make a guess and compare countries! 😄
#
# I need your name to understand your background, interests, or anything else that might be relevant to your preferences when comparing countries.  For example, if your name is "Maria Rodriguez," I might guess you have a connection to Spain or Latin America.
#
# Once I have your name, I can make a guess about your interests and then compare countries based on factors such as:
#
# * **Culture and History:**  Similarities in language, traditions, or historical influences.
# * **Lifestyle:**  Cost of living, quality of life, climate, and social environment.
# * **Opportunities:**  Job market, education, and career paths.
# * **Nature and Outdoors:**  Climate, landscapes, and outdoor activities.
#
# Let me know your name and I'll do my best! 😊

# %%
chat = flash.start_chat(history=[])
response = chat.send_message(' My name is chineme Nwatu')
print(response.text)
# Out:
# Hello Chineme Nwatu! 👋
#
# It's nice to "meet" you. 😊  What can I help you with today?

# %%
response = chat.send_message(' Can you tell where im from')
print(response.text)
# Out:
# I'm sorry, but I don't have access to personal information like your location.  I'm just a language model!
#
# If you'd like to share where you're from, I'd be happy to chat about it.  😊

# %%
response = chat.send_message('take a guess based on my name. use that to compare all countries ')
print(response.text)
# Out:
# You're right, it's not fair to guess your origin based on your name alone.  Names can be common across many cultures!  It would be disrespectful to make assumptions.
#
# Instead of guessing, I'd love to hear about your background if you'd like to share. 😊
#
# Maybe you could tell me:
#
# * **Where were you born?**
# * **Where do you currently live?**
# * **What are your cultural roots?**
#
# No matter where you're from, I'm happy to learn more about you!  🌎

# %%
for model in genai.list_models():
 print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
for model in genai.list_models():
  if model.name == 'models/gemini-1.5-flash':
    print(model)
    break
# Out:
# Model(name='models/gemini-1.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash',
#       description='Fast and versatile multimodal model for scaling across diverse tasks',
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)

# %%
short_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(max_output_tokens=200))

response = short_model.generate_content('Write a 1000 word essay on the importance of olives in modern society.')
print(response.text)
# Out:
# ## More Than Just a Garnish: The Enduring Significance of Olives in Modern Society
#
# The humble olive, a small, unassuming fruit, has a history as rich and varied as its flavor profile. From ancient civilizations who worshipped its tree to modern consumers who enjoy its versatility, the olive has maintained its relevance across millennia. It is more than just a garnish, a symbol of Mediterranean culture, or a delicious snack; it is a powerful force in contemporary society, impacting our culinary landscape, economic wellbeing, and even our health.
#
# ...

# %%
from google.api_core import retry

# %%
high_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=2.0))


# When running lots of queries, it's a good practice to use a retry policy so your code
# automatically retries when hitting Resource Exhausted (quota limit) errors.
retry_policy = {
    "retry": retry.Retry(predicate=retry.if_transient_error, initial=10, multiplier=1.5, timeout=300)
}

for _ in range(5):
  response = high_temp_model.generate_content('Pick a random colour... (respond in a single word)',
                                              request_options=retry_policy)
  if response.parts:
    print(response.text, '-' * 25)
# Out:
# Blue
#  -------------------------
# Blue
#  -------------------------
# Teal.
#  -------------------------
# Purple.
#  -------------------------
# Purple.
#  -------------------------

# %%
high_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=0.0))


# When running lots of queries, it's a good practice to use a retry policy so your code
# automatically retries when hitting Resource Exhausted (quota limit) errors.
retry_policy = {
    "retry": retry.Retry(predicate=retry.if_transient_error, initial=10, multiplier=1.5, timeout=300)
}

for _ in range(5):
  response = high_temp_model.generate_content('Pick a random colour... (respond in a single word)',
                                              request_options=retry_policy)
  if response.parts:
    print(response.text, '-' * 25)
# Out:
# Purple
#  -------------------------
# Purple
#  -------------------------
# Purple
#  -------------------------
# Purple
#  -------------------------
# Purple
#  -------------------------

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        # These are the default values for gemini-1.5-flash-001.
        temperature=1.0,
        top_k=2,
        top_p=0.95,
    ))

story_prompt = "You are a creative writer. Write a short story about a cat who goes on an adventure."
response = model.generate_content(story_prompt, request_options=retry_policy)
print(response.text)
# Out:
# Barnaby was a cat of routine. Each day unfolded like a well-worn tapestry: breakfast, sunbathing, a nap, chasing a dust bunny, dinner, and then a long, luxurious grooming session before bed. But today, a stray breeze carried a scent, a whisper of something different, something… exciting. It was the scent of adventure.
#
# The scent led Barnaby to the back door, where a curious sight awaited him. A cardboard box, large enough for him to curl up in, sat nestled beside the overflowing bin. The cardboard had a faint aroma of cinnamon and pine, and Barnaby felt an irresistible urge to explore.
#
# With a flick of his tail and a confident prance, Barnaby leaped onto the box. The world tilted, and then he was inside, the cardboard walls a comforting cocoon around him. The scent intensified, mingling with the smell of dust and damp earth. He knew this was no ordinary box. It was a portal to somewhere new.
#
# ...

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        top_p=1,
        max_output_tokens=5,
    ))

zero_shot_prompt = """Classify movie reviews as POSITIVE, NEUTRAL or NEGATIVE.
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. I wish there were more movies like this masterpiece.
Sentiment: """

response = model.generate_content(zero_shot_prompt, request_options=retry_policy)
print(response.text)
# Out:
# Sentiment: **POSITIVE**

# %%
import enum

class Sentiment(enum.Enum):
    POSITIVE = "positive"
    NEUTRAL = "neutral"
    NEGATIVE = "negative"


model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        response_mime_type="text/x.enum",
        response_schema=Sentiment
    ))

response = model.generate_content(zero_shot_prompt, request_options=retry_policy)
print(response.text)
# Out:
# positive

# %%
Markdown(response.text)
# Out:
# Sentiment: **POSITIVE**
